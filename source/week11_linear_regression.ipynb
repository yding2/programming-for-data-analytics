# %% [markdown]
# # Linear Regression

# %% [markdown]
# ### Multiple Linear Regression

# %% [markdown]
# Let's read the dataset first.

# %%
# Read the data set from the website of our textbook
auto = pd.read_csv('https://www.statlearning.com/s/Auto.csv')
# Here I dropped the records with horsepower = ?
auto = auto.drop(labels=[32,126,330,336,354], axis=0)

# %% [markdown]
# Let's split the data set into two parts *auto_training* and *auto_test*.

# %%
auto_training = auto.sample(frac = 0.8)
auto_test = auto.drop(auto_training.index)

# %%
# choose the predictor
X = pd.DataFrame(auto_training[['cylinders','displacement','horsepower','weight','acceleration','year','origin']])
# choose the response
y = auto_training[['mpg']]
# add a constant to the predictor
X = sm.add_constant(X)
# OLS stands for “Ordinary Least Squares”
# `horsepower` consider as a object, so I use astype to convert it to numeric
model01 = sm.OLS(y, X.astype(float)).fit()
# To obtain the results of the regression model, run the `summary()` command on the model
model01.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.818
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     196.1
# Date:                Tue, 31 Mar 2026   Prob (F-statistic):          4.33e-109
# Time:                        21:21:07   Log-Likelihood:                -821.26
# No. Observations:                 314   AIC:                             1659.
# Df Residuals:                     306   BIC:                             1689.
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -18.1994      5.260     -3.460      0.001     -28.550      -7.849
# cylinders       -0.3952      0.354     -1.116      0.265      -1.092       0.302
# displacement     0.0158      0.008      1.899      0.059      -0.001       0.032
# horsepower      -0.0094      0.015     -0.610      0.543      -0.040       0.021
# weight          -0.0062      0.001     -8.697      0.000      -0.008      -0.005
# acceleration     0.1817      0.114      1.599      0.111      -0.042       0.405
# year             0.7213      0.058     12.509      0.000       0.608       0.835
# origin           1.5501      0.321      4.823      0.000       0.918       2.182
# ==============================================================================
# Omnibus:                       27.498   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.367
# Skew:                           0.538   Prob(JB):                     8.54e-11
# Kurtosis:                       4.544   Cond. No.                     8.72e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.72e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_test = pd.DataFrame(auto_test[['cylinders','displacement','horsepower','weight','acceleration','year','origin']])
X_test = sm.add_constant(X_test.astype(float))
ypred = model01.predict(X_test)

# %% [markdown]
# We can use *sklearn* package to calculate the assessment measures directly.

# %%
from sklearn import metrics 
# calculate MAE, MSE, RMSE
print(metrics.mean_absolute_error(y_true = auto_test[['mpg']], y_pred = ypred))
print(metrics.mean_squared_error(y_true = auto_test[['mpg']], y_pred = ypred))
# Out:
# 6.357588388270444
# 60.94616016277276
